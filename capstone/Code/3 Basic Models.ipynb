# %% [markdown]
# **In previous notebooks we cleaned and analysed the data and topics associated with the comments. Now we will use the cleaned and lemmatized data for modelling.**

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, confusion_matrix, plot_roc_curve, classification_report

import pickle

from google.colab import drive

# %% [markdown]
# ## Import Cleaned Data

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Capstone/Data/

# %%
train = pd.read_csv("train_clean_lemmatize.csv")
# Out:
# /content/drive/My Drive/Capstone/Data

# %%
train.head()
# Out:
#       id  ...  target_label
# 0  59848  ...             0
# 1  59849  ...             0
# 2  59852  ...             0
# 3  59855  ...             0
# 4  59856  ...             1
#
# [5 rows x 35 columns]

# %%
train.shape
# Out:
# (1778628, 35)

# %%
train['target_label'].value_counts()
# Out:
# 0    1636193
# 1     142435
# Name: target_label, dtype: int64

# %% [markdown]
# We have imbalanced comments data, toxic comments being the minor class in comparision to the non toxic comments.

# %% [markdown]
# ## Declare Features & Target

# %% [markdown]
# Declaring the feature and target for models. We will use lemmatized comments for the base models to predict the toxic comments labelled in target_label.

# %%
X = train['comment_lemmatized']
y = train['target_label']

# %% [markdown]
# ## Train/Test Split

# %% [markdown]
# We will then split our data into train and validation set and stratify by y so that our subsets have equal distribution of the labels.

# %%
X_train, X_val, y_train, y_val = train_test_split(X, 
                                                  y, 
                                                  stratify = y,
                                                  random_state = 42)

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (1333971,) (1333971,) (444657,) (444657,)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.919919
# 1    0.080081
# Name: target_label, dtype: float64

# %%
y_val.value_counts(normalize=True)
# Out:
# 0    0.919918
# 1    0.080082
# Name: target_label, dtype: float64

# %% [markdown]
# Here we can see that the train and validation set have even distribution of the toxic and non toxic labels.

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Tokenize Using TfidVectorizer

# %% [markdown]
# Before modelling we need to convert the text comments into a feature matrix. The min_df, max_df and ngram_range has been selected after few trials.

# %%
tfvec = TfidfVectorizer(min_df=5,  
                        max_df = 0.9,
                        ngram_range = (1,2))

# %%
X_train_tfvec = tfvec.fit_transform(X_train)
X_val_tfvec = tfvec.transform(X_val)

# %% [markdown]
# ### Model Function

# %%
def create_model(model, params):
    '''
    Common function to use for modelling
    '''

    # Declaring model metrics that we will return at the end of the function
    metrics = {}

    # Initialize gridsearch for model based on params passed
    gs = GridSearchCV(model, param_grid=params, cv=5, scoring='roc_auc', n_jobs=-1)

    # Fit the model
    gs.fit(X_train_tfvec, y_train)

    # Best parameters
    best_params = gs.best_params_

    # Best model
    best_model = gs.best_estimator_

    # Fit the best model
    best_model.fit(X_train_tfvec, y_train)

    # Predic validation set
    predictions = best_model.predict(X_val_tfvec)

    # Metrics
    train_pred_prob = best_model.predict_proba(X_train_tfvec)[:,1]
    test_pred_prob = best_model.predict_proba(X_val_tfvec)[:,1]
    roc_auc_train = roc_auc_score(y_train, train_pred_prob)
    roc_auc_val = roc_auc_score(y_val, test_pred_prob)
    tn, fp, fn, tp = confusion_matrix(y_val, predictions).ravel()
    sensitivity = tp/(tp + fn)
    specificity = tn/(tn + fp)
    accuracy = (tn + tp)/(tn + tp + fn + fp)
  
    metrics['roc_auc_train'] = roc_auc_train
    metrics['roc_auc_val'] = roc_auc_val
    metrics['accuracy'] = accuracy
    metrics['sensitivity'] = sensitivity
    metrics['specificity'] = specificity
    metrics['FalsePos'] = fp
    metrics['TruePos'] = tp
    metrics['FalseNeg'] = fn
    metrics['TrueNeg'] = tn
  
    return (best_params, best_model, metrics)

# %% [markdown]
# ### Logistic Regression

# %%
# Declare grid search parameters

lr_params = {
    'penalty':['l2','l1'], 
    'C': [0.8, 1],
    'max_iter':[3000],
    'random_state':[42]
}

lr_model = LogisticRegression()

lr_best_params, lr_best_model, lr_metrics = create_model(lr_model, params=lr_params)

print(lr_best_params)
print(lr_metrics)
# Out:
# {'C': 1, 'max_iter': 3000, 'penalty': 'l2', 'random_state': 42}
# {'roc_auc_train': 0.9715131888730236, 'roc_auc_val': 0.945063386589076, 'accuracy': 0.9453174019525162, 'sensitivity': 0.43497430424892586, 'specificity': 0.9897444798654437, 'FalsePos': 4195, 'TruePos': 15489, 'FalseNeg': 20120, 'TrueNeg': 404853}

# %% [markdown]
# Saving the Logistic Regression model for future use.

# %%
filename = '/content/drive/My Drive/Capstone/Code/BaseModels/LogisticRegression.pkl'
pickle.dump(lr_best_model, open(filename, 'wb'))

# %%
#lr_best_model = pickle.load(open(filename, 'rb'))

# %%
features = tfvec.get_feature_names()
features[:20]
# Out:
# ['aa',
#  'aa aa',
#  'aa anoth',
#  'aa bee',
#  'aa degre',
#  'aa group',
#  'aa help',
#  'aa html',
#  'aa left',
#  'aa meet',
#  'aa na',
#  'aa poor',
#  'aa religi',
#  'aa say',
#  'aa stori',
#  'aa usual',
#  'aaa',
#  'aaa anoth',
#  'aaa bond',
#  'aaa credit']

# %%
feature_coef = pd.DataFrame({'Feature': tfvec.get_feature_names(), 'coef': lr_best_model.coef_[0]})

# %%
pd.set_option('display.max_rows', None)
feature_coef.sort_values(by='coef', ascending=False).head(100)
# Out:
#             Feature       coef
# 976459       stupid  45.570819
# 481391        idiot  42.148934
# 731276       pathet  23.813259
# 478738     hypocrit  23.409914
# 231892         crap  21.993476
# 648985        moron  21.321607
# 295476         dumb  20.632807
# 383759         fool  19.567671
# 866157      ridicul  18.856028
# 243813         damn  18.822865
# 67866           ass  17.230997
# 520053         jerk  17.157516
# 402715       garbag  16.702755
# 917660         shit  16.498242
# 592010        loser  16.380132
# 925084        silli  16.286426
# 481375       idioci  16.194136
# 384027      foolish  16.102404
# 182103        clown  16.023609
# 485187      imbecil  15.747757
# 894977         scum  15.128655
# 565825         liar  14.286397
# 481949        ignor  14.282946
# 979858         suck  14.192843
# 125556      buffoon  13.610669
# 396003         fuck  13.386744
# 875106      rubbish  13.111583
# 244958         darn  13.006842
# 231334       coward  12.779954
# 127514     bullshit  12.522042
# 295643      dumbest  12.283200
# 1075900     useless  12.251869
# 894995      scumbag  11.736191
# 478585    hypocrisi  11.727564
# 597843        lunat  11.449226
# 69032        asshol  11.092031
# 977040    stupidest  11.063081
# 278782      disgust  10.978550
# 808758        pussi  10.625248
# 89173       bastard  10.619065
# 403874          gay  10.252059
# 1039904       trash  10.106762
# 109295        bitch  10.078411
# 980012       sucker   9.981120
# 749795          pig   9.938750
# 736191         peni   9.775410
# 1044584       troll   9.620532
# 109522        black   9.486578
# 722955      parasit   9.486295
# 498555        inept   9.449714
# 295629       dumber   9.415451
# 1038541     traitor   9.351238
# 1113422       whore   9.073248
# 533108         kill   8.681897
# 232275        crazi   8.670760
# 894591        screw   8.534735
# 526729         junk   8.479554
# 597680       ludicr   8.472943
# 64036           ars   8.155034
# 658071       muslim   7.908168
# 913964          sex   7.897459
# 819955         rape   7.883953
# 977049     stupidli   7.843457
# 493259     incompet   7.645195
# 681284      nonsens   7.538991
# 63862         arrog   7.508849
# 234640       cretin   7.492457
# 816450       racist   7.482788
# 891515      schmuck   7.464162
# 922269         sick   7.453408
# 820265       rapist   7.426516
# 914668           sh   7.368140
# 1077601      vagina   7.306748
# 274098       dimwit   7.301732
# 66458        asinin   7.249018
# 232043       crappi   7.243908
# 1111948       white   7.174677
# 938070    sociopath   7.143784
# 861415       retard   7.102702
# 467911     homosexu   7.086484
# 130814         butt   6.977373
# 237513        crook   6.871589
# 820551          rat   6.833138
# 220385      corrupt   6.830936
# 1022966        thug   6.810823
# 662020   narcissist   6.800686
# 518663      jackass   6.715560
# 455687         hell   6.705096
# 640911        miser   6.692077
# 242998         daft   6.684850
# 483017     ignoramu   6.663758
# 687739          nut   6.580938
# 275433        dirti   6.569514
# 1058332        ugli   6.516675
# 231394     cowardli   6.507182
# 917957        shoot   6.495023
# 267089       despic   6.480390
# 615865      masturb   6.427296
# 746091      pervert   6.424018
# 370733       filthi   6.410218

# %%
np.max(lr_best_model.coef_[0])
# Out:
# 45.570819491813836

# %%
len(features)
# Out:
# 1148538

# %%
plt.figure(figsize=(20,15))
lr_disp = plot_roc_curve(lr_best_model, X_val_tfvec, y_val)

# %%
preds = lr_best_model.predict(X_val_tfvec)

# %%
print(classification_report(y_val, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    409048
#            1       0.79      0.43      0.56     35609
#
#     accuracy                           0.95    444657
#    macro avg       0.87      0.71      0.77    444657
# weighted avg       0.94      0.95      0.94    444657

# %%
preds_df = pd.DataFrame({'comments' : X_val.tolist(), 'actual' : y_val.tolist(), 'prediction' : preds})

# %%
preds_df.head()
# Out:
#                                             comments  actual  prediction
# 0  wow wow canadian doom anoth year con led proba...       0           0
# 1             place american societi neo nazi period       0           0
# 2    anyon know said kamehameha ugliest man ever met       0           0
# 3  articl like make asham canadian randl reef ham...       0           0
# 4  well said barb unfortun column like denis writ...       0           0

# %%
preds_df['actual'].value_counts()
# Out:
# 0    409048
# 1     35609
# Name: actual, dtype: int64

# %%
preds_df['prediction'].value_counts()
# Out:
# 0    424973
# 1     19684
# Name: prediction, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   first comment thread say mani muslim shown mock trudeau ramadan sock latest claim trudeau spoke long loud disparag teepe comment sure lot miser peopl long weekend  ...           0
# 332                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   gay fulli awar mani muslim consid death bless upon  ...           0
# 362                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      quit funni post mani level one hand funni impli immigr popul commit sexual assault swedish women funni trivial crime victim thu see life laiti involv mock victim pretend concern crime trivial truli christian act consist teach jesu christ interpret theolog one true church  ...           0
# 379                                                                                                                                                                                                                                                                                                                                                                                                                         assum middl class includ high incom earn support industri oil compani racket health care complex alaska state carpetbag oil industri worker ceo sharehold around world profit natur resourc get idea head peopl paid worth koch brother inherit wealth make time per hour nurs aid lazi ass nurs aid live bush may job lazi ass tough cultur co opt want nice school commun kid could part domin cultur rais stone age style instead sure middl class self righteou type invent western cultur materi wealth independ aid ingeni bootstrap share lazi villag  ...           0
# 384                                                                                                                                                                                                                                                                                                                                                                                                                    make sens canada trudeau alreadi gotten headlin step plate compass virtu take refuge other impact trump travel ban one go find emerson problem enough alreadi look technic save face necessari similar theatric whether canada right thing sell billion dollar arm worst human right violat world one found either get keep money peac love honest broker stuff along line european countri marvel rel eas canada bring ten thousand syrian compar chao countri know secret seem limit influx orphan famili homosexu would stupid let info alreadi gotten headlin  ...           0
# 399                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             mid age men simpli matter close mid age white men matter  ...           0
# 414                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     actual familiar subject matter topic obvious limit found wikipedia claim lack knowledg result civil comment softwar internet version dog ate homework anim right spokesman told right punch pig life grandson equal marvel way debat subject physic violenc said hitler thought exhibit attitud swift satir reveal lack familiar work author irish australian alaskan hawaiian histori cultur research post less  ...           0
#
# [20 rows x 3 columns]

# %% [markdown]
# ### Random Forest Classifier

# %%
# Declare grid search parameters

rf_params = {
    'n_estimators':[100, 150, 190], 
    'class_weight': ['balanced'],
    'max_depth':[3, 4, 5],
    'random_state':[42]
}

rf_model = RandomForestClassifier()

rf_best_params, rf_best_model, rf_metrics = create_model(rf_model, params=rf_params)

print(rf_best_params, rf_metrics)
# Out:
# {'class_weight': 'balanced', 'max_depth': 5, 'n_estimators': 190, 'random_state': 42} {'roc_auc_train': 0.8296969172857451, 'roc_auc_val': 0.8227626031007639, 'accuracy': 0.8334401572447977, 'sensitivity': 0.6681737762925103, 'specificity': 0.8478271498699419, 'FalsePos': 62246, 'TruePos': 23793, 'FalseNeg': 11816, 'TrueNeg': 346802}

# %%
filename_rf = '/content/drive/My Drive/Capstone/Code/BaseModels/RandomForest.pkl'
pickle.dump(rf_best_model, open(filename_rf, 'wb'))

# %%
preds_rf = rf_best_model.predict(X_val_tfvec)

# %%
print(classification_report(y_val, preds_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90    409048
#            1       0.28      0.67      0.39     35609
#
#     accuracy                           0.83    444657
#    macro avg       0.62      0.76      0.65    444657
# weighted avg       0.91      0.83      0.86    444657

# %%
plt.figure(figsize=(20,15))
rf_disp = plot_roc_curve(rf_best_model, X_val_tfvec, y_val)
